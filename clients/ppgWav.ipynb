# %%
import heartpy as hp
import pandas as pd

pd.options.plotting.backend = "plotly"
ppgData = pd.read_csv('./ppg_out.csv')

hp.peakdetection.make_windows(data=ppgData['1'], windowsize=256, sample_rate=200)

for i in range(ppgData['1'].size):
    ppgData['1'][i] = (1/ppgData['1'][i]) * 10000000
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [58], line 7
#       4 pd.options.plotting.backend = "plotly"
#       5 ppgData = pd.read_csv('./ppg_out.csv')
# ----> 7 hp.peakdetection.make_windows(data=ppgData['1'], windowsize=256)
#       9 for i in range(ppgData['1'].size):
#      10     ppgData['1'][i] = (1/ppgData['1'][i]) * 10000000
#
# TypeError: make_windows() missing 1 required positional argument: 'sample_rate'

# %%
ppgData['1']
# Out:
# 0       39.036120
# 1       39.029721
# 2       39.023477
# 3       39.014798
# 4       39.008863
#           ...
# 7263    38.989699
# 7264    39.053347
# 7265    39.121182
# 7266    39.189406
# 7267    39.253400
# Name: 1, Length: 7268, dtype: float64

# %%
fig = ppgData['1'].plot()
fig.show()
